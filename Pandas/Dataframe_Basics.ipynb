# %%
import pandas as pd
df = pd.read_csv('.\\data.csv')
df
# Out:
#     NAMES  COMPUTERS  MATH  ECE
# 0       1         81    76   34
# 1       2         35    57   56
# 2       3         76     2   76
# 3       4         84    32   87
# 4       5         74    98   43
# 5       6         87    89   65
# 6       7         67    58   87
# 7       8         45    48   47
# 8       9         31    98   86
# 9      10         43    34   35
# 10     11         99    56    9
# 11     12          5    86   84
# 12     13         18    89   94
# 13     14         55    90   89
# 14     15         38    67   67
# 15     16         16    87   45
# 16     17         20    45   31
# 17     18         16    76   43
# 18     19         86    98   81
# 19     20         35    76   11
# 20     21         76    57   35
# 21     22         84    35   86
# 22     23         74    86   98
# 23     24         89    98   89
# 24     25         94    89   58
# 25     26         45    58   67
# 26     27         31    67   98
# 27     28         43    98   34
# ...

# %%
df.shape
# Out:
# (60, 4)

# %%
df.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-412feca855b9> in <module>
# ----> 1 df.rows
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
rows,colums = df.shape

# %%
rows
# Out:
# 60

# %%
columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8e7b9895361f> in <module>
# ----> 1 columns
#
# NameError: name 'columns' is not defined

# %%
colums
# Out:
# 4

# %%
df.head()
# Out:
#    NAMES  COMPUTERS  MATH  ECE
# 0      1         81    76   34
# 1      2         35    57   56
# 2      3         76     2   76
# 3      4         84    32   87
# 4      5         74    98   43

# %%
df.tail()
# Out:
#     NAMES  COMPUTERS  MATH  ECE
# 55     56         54    76   11
# 56     57         37    98   18
# 57     58         78    45   55
# 58     59         12    67   38
# 59     60         14   100   55

# %%
df.tail(3)
# Out:
#     NAMES  COMPUTERS  MATH  ECE
# 57     58         78    45   55
# 58     59         12    67   38
# 59     60         14   100   55

# %%
df.head(7)
# Out:
#    NAMES  COMPUTERS  MATH  ECE
# 0      1         81    76   34
# 1      2         35    57   56
# 2      3         76     2   76
# 3      4         84    32   87
# 4      5         74    98   43
# 5      6         87    89   65
# 6      7         67    58   87

# %%
df[2:5]
# Out:
#    NAMES  COMPUTERS  MATH  ECE
# 2      3         76     2   76
# 3      4         84    32   87
# 4      5         74    98   43

# %%
df[:]  #df
# Out:
#     NAMES  COMPUTERS  MATH  ECE
# 0       1         81    76   34
# 1       2         35    57   56
# 2       3         76     2   76
# 3       4         84    32   87
# 4       5         74    98   43
# 5       6         87    89   65
# 6       7         67    58   87
# 7       8         45    48   47
# 8       9         31    98   86
# 9      10         43    34   35
# 10     11         99    56    9
# 11     12          5    86   84
# 12     13         18    89   94
# 13     14         55    90   89
# 14     15         38    67   67
# 15     16         16    87   45
# 16     17         20    45   31
# 17     18         16    76   43
# 18     19         86    98   81
# 19     20         35    76   11
# 20     21         76    57   35
# 21     22         84    35   86
# 22     23         74    86   98
# 23     24         89    98   89
# 24     25         94    89   58
# 25     26         45    58   67
# 26     27         31    67   98
# 27     28         43    98   34
# ...

# %%
df[:,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-542ea5bfd780> in <module>
# ----> 1 df[:,2]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2893             casted_key = self._maybe_cast_indexer(key)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#    2897                 raise KeyError(key) from err
#
# ...

# %%
df.row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-a0fe53b7fddd> in <module>
# ----> 1 df.row
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
df.colums
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-9962f18f67b6> in <module>
# ----> 1 df.colums
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'colums'

# %%
df.columns
# Out:
# Index(['NAMES', 'COMPUTERS', 'MATH', 'ECE'], dtype='object')

# %%
df.event
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d3c3dcab4631> in <module>
# ----> 1 df.event
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'event'

# %%
df['event']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'event'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-5d9888486f1b> in <module>
# ----> 1 df['event']
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#     NAMES  COMPUTERS  MATH  ECE
# 0       1         81    76   34
# 1       2         35    57   56
# 2       3         76     2   76
# 3       4         84    32   87
# 4       5         74    98   43
# 5       6         87    89   65
# 6       7         67    58   87
# 7       8         45    48   47
# 8       9         31    98   86
# 9      10         43    34   35
# 10     11         99    56    9
# 11     12          5    86   84
# 12     13         18    89   94
# 13     14         55    90   89
# 14     15         38    67   67
# 15     16         16    87   45
# 16     17         20    45   31
# 17     18         16    76   43
# 18     19         86    98   81
# 19     20         35    76   11
# 20     21         76    57   35
# 21     22         84    35   86
# 22     23         74    86   98
# 23     24         89    98   89
# 24     25         94    89   58
# 25     26         45    58   67
# 26     27         31    67   98
# 27     28         43    98   34
# ...

# %%
df['MATH']
# Out:
# 0      76
# 1      57
# 2       2
# 3      32
# 4      98
# 5      89
# 6      58
# 7      48
# 8      98
# 9      34
# 10     56
# 11     86
# 12     89
# 13     90
# 14     67
# 15     87
# 16     45
# 17     76
# 18     98
# 19     76
# 20     57
# 21     35
# 22     86
# 23     98
# 24     89
# 25     58
# 26     67
# 27     98
# 28     34
# 29     56
# 30     86
# 31     77
# 32     90
# 33     67
# 34     87
# 35     45
# 36     76
# 37     98
# 38     76
# 39     57
# 40     35
# 41     86
# 42     98
# 43     89
# 44     58
# 45     67
# 46     98
# 47     34
# 48     56
# 49     86
# 50     89
# 51     90
# 52     67
# 53     87
# 54     45
# 55     76
# 56     98
# 57     45
# 58     67
# 59    100
# Name: MATH, dtype: int64

# %%
df['MATH'].max()
# Out:
# 100

# %%
df['ECE'].mean()
# Out:
# 61.583333333333336

# %%
df['COMPUTERS']
# Out:
# 0     81
# 1     35
# 2     76
# 3     84
# 4     74
# 5     87
# 6     67
# 7     45
# 8     31
# 9     43
# 10    99
# 11     5
# 12    18
# 13    55
# 14    38
# 15    16
# 16    20
# 17    16
# 18    86
# 19    35
# 20    76
# 21    84
# 22    74
# 23    89
# 24    94
# 25    45
# 26    31
# 27    43
# 28    81
# 29    11
# 30    18
# 31    55
# 32    38
# 33    16
# 34    84
# 35    16
# 36    41
# 37    35
# 38    76
# 39    84
# 40    74
# 41    89
# 42    67
# 43    45
# 44    31
# 45    73
# 46    81
# 47    11
# 48    18
# 49    55
# 50    38
# 51    16
# 52    73
# 53    16
# 54    45
# 55    54
# 56    37
# 57    78
# 58    12
# 59    14
# Name: COMPUTERS, dtype: int64

# %%
df['COMPUTERS'].mode()
# Out:
# 0    16
# dtype: int64

# %%
df.describe() #statistics of data
# Out:
#            NAMES  COMPUTERS        MATH        ECE
# count  60.000000  60.000000   60.000000  60.000000
# mean   30.500000  50.483333   71.166667  61.583333
# std    17.464249  27.665368   22.647757  25.210498
# min     1.000000   5.000000    2.000000   9.000000
# 25%    15.750000  28.250000   56.750000  43.000000
# 50%    30.500000  45.000000   76.000000  66.000000
# 75%    45.250000  76.000000   89.000000  86.000000
# max    60.000000  99.000000  100.000000  98.000000

# %%
df[df.MATH >92]
# Out:
#     NAMES  COMPUTERS  MATH  ECE
# 4       5         74    98   43
# 8       9         31    98   86
# 18     19         86    98   81
# 23     24         89    98   89
# 27     28         43    98   34
# 37     38         35    98   76
# 42     43         67    98   76
# 46     47         81    98   67
# 56     57         37    98   18
# 59     60         14   100   55

# %%
df.plot('MATH','ECE')
# Out:
# <AxesSubplot:xlabel='MATH'>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=60, step=1)
